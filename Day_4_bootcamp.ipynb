# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("Modiji.png")
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (808, 682, 3)

# %%
cv2.imshow("Photos", img)
cv2.waitKey(0)
# Out:
# -1

# %%
img_resize=cv2.resize(img, (400,256))
cv2.imshow("Photos", img_resize)
cv2.waitKey(0)
# Out:
# -1

# %%
img_flip = cv2.flip(img,0)
cv2.imshow("Photos", img_flip)
cv2.waitKey(0)
# Out:
# -1

# %%
img_crop = img[100:300, 200:500]
cv2.imshow("Photos", img_crop)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in c:\users\hp\anaconda3\lib\site-packages (8.4.161)
# Requirement already satisfied: opencv-python in c:\users\hp\anaconda3\lib\site-packages (5.0.0.93)
# Requirement already satisfied: cloudpickle>=3.1.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (3.1.1)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (3.20.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.3.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: torch>=1.8.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.14.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (0.29.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (1.44.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.1.6 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.1.6)
# Requirement already satisfied: ultralytics-platform>=0.1.45 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (0.1.62)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.44.2 in c:\users\hp\anaconda3\lib\site-packages (from polars>=0.20.0->ultralytics) (1.44.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.28 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics-platform>=0.1.45->ultralytics) (0.28.1)
# Requirement already satisfied: anyio in c:\users\hp\anaconda3\lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from ultralytics import settings

# Disable data and crash report tracking
settings.update({"sync": False})
from ultralytics import YOLO

# 1. Load the lightweight YOLOv8 Nano model (~6MB, runs fast on CPU)
model = YOLO('yolov8n.pt')

# 2. Open the webcam (0 is default built-in camera)
cap = cv2.VideoCapture(0)

print("Starting Object Counter... Press 'q' on the video window to quit.")

while cap.isOpened():
  success, frame = cap.read()
  if not success:
    print("Failed to grab camera frame.")
    break

  # 3. Perform object detection on the current frame
  results = model(frame, verbose=False)

  # Get total number of objects detected in this frame
  detected_count = len(results[0].boxes)

  # 4. Render detection boxes directly on the frame
  annotated_frame = results[0].plot()

  # 5. Display the object count overlay on screen
  cv2.putText(
      annotated_frame,
      f'Total Objects Counted: {detected_count}',
      (20, 50),  # Position (x, y)
      cv2.FONT_HERSHEY_SIMPLEX,
     1,  # Font scale
      (0, 255, 0),  # Text color (Green)
      2,  # Thickness
      cv2.LINE_AA,
  )

  # 6. Show the frame in a window
  cv2.imshow('BCA AI Demo - Live Object Counter', annotated_frame)

  # 7. Terminate program cleanly when pressing 'q'
  if cv2.waitKey(1) & 0xFF == ord('q'):
    print("Terminating program...")
    break

# Release camera and close all windows cleanly
cap.release()

# 2. Add short wait key loops to let Windows pump destroy events cleanly
cv2.waitKey(1)
cv2.destroyAllWindows()
cv2.waitKey(1)

print("Camera feed closed successfully.")
# Out:
# Creating new Ultralytics Settings v0.0.8 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\HP\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 314.3KB/s 20.3s.3s<0.1s0.4s
# Starting Object Counter... Press 'q' on the video window to quit.
